# %%
import sys
# adding to the path variables the one folder higher (locally, not changing system variables)
sys.path.append("..")
import pandas as pd
import numpy as np
import warnings
import mlflow
from modeling.config import TRACKING_URI, EXPERIMENT_NAME

pd.set_option('display.max_columns', None)

RSEED = 42
# Modeling Libraries

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px  # pip install plotly needs to executed
import plotly.graph_objects as go

# %%
df = pd.read_csv('../data/Flu_Shot_Data_cleaned_2.csv')

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %% [markdown]
# ## Examining correlations between features

# %%
df.corr(method='spearman')
# Out:
#                              h1n1_vaccine  seasonal_vaccine  h1n1_concern  \
# h1n1_vaccine                     1.000000          0.377143      0.122666
# seasonal_vaccine                 0.377143          1.000000      0.154467
# h1n1_concern                     0.122666          0.154467      1.000000
# h1n1_knowledge                   0.120748          0.121633      0.058046
# behavioral_antiviral_meds        0.040608          0.006277      0.090914
# behavioral_avoidance             0.047690          0.076395      0.230672
# behavioral_face_mask             0.070498          0.050083      0.157175
# behavioral_wash_hands            0.074712          0.112414      0.291068
# behavioral_large_gatherings      0.017822          0.064025      0.259242
# behavioral_outside_home          0.021768          0.053509      0.250697
# behavioral_touch_face            0.071648          0.120228      0.248786
# doctor_recc_h1n1                 0.393890          0.198607      0.152314
# doctor_recc_seasonal             0.209864          0.369190      0.136396
# chronic_med_condition            0.095207          0.170174      0.096359
# child_under_6_months             0.066962          0.012097      0.050583
# health_worker                    0.169768          0.127311      0.034141
# health_insurance                 0.121170          0.200858     -0.003231
# opinion_h1n1_vacc_effective      0.291602          0.201753      0.220374
# opinion_h1n1_risk                0.305840          0.219161      0.386032
# opinion_h1n1_sick_from_vacc      0.059032          0.030128      0.368674
# opinion_seas_vacc_effective      0.195961          0.397874      0.222948
# opinion_seas_risk                0.256199          0.389286      0.336218
# opinion_seas_sick_from_vacc     -0.002808         -0.075427      0.225148
# household_adults                 0.013360         -0.058912     -0.013091
# household_children              -0.002012         -0.121141      0.054138
#
#                              h1n1_knowledge  behavioral_antiviral_meds  \
# h1n1_vaccine                       0.120748                   0.040608
# seasonal_vaccine                   0.121633                   0.006277
# h1n1_concern                       0.058046                   0.090914
# h1n1_knowledge                     1.000000                  -0.007249
# behavioral_antiviral_meds         -0.007249                   1.000000
# behavioral_avoidance               0.082288                   0.049247
# behavioral_face_mask               0.033785                   0.146261
# behavioral_wash_hands              0.088010                   0.064119
# behavioral_large_gatherings       -0.045385                   0.106287
# behavioral_outside_home           -0.063482                   0.127679
# behavioral_touch_face              0.086909                   0.070868
# doctor_recc_h1n1                   0.095197                   0.051235
# doctor_recc_seasonal               0.073031                   0.030909
# chronic_med_condition             -0.018905                   0.008465
# child_under_6_months               0.024308                   0.028788
# health_worker                      0.174527                   0.009465
# health_insurance                   0.119876                  -0.063988
# opinion_h1n1_vacc_effective        0.128278                   0.036185
# opinion_h1n1_risk                  0.076609                   0.091523
# opinion_h1n1_sick_from_vacc       -0.026393                   0.071785
# opinion_seas_vacc_effective        0.081695                   0.022263
# opinion_seas_risk                  0.077751                   0.082382
# opinion_seas_sick_from_vacc       -0.072194                   0.076568
# household_adults                   0.036928                   0.040678
# household_children                 0.054768                   0.086445
#
#                              behavioral_avoidance  behavioral_face_mask  \
# h1n1_vaccine                             0.047690              0.070498
# seasonal_vaccine                         0.076395              0.050083
# h1n1_concern                             0.230672              0.157175
# h1n1_knowledge                           0.082288              0.033785
# behavioral_antiviral_meds                0.049247              0.146261
# behavioral_avoidance                     1.000000              0.064946
# behavioral_face_mask                     0.064946              1.000000
# behavioral_wash_hands                    0.338130              0.083363
# behavioral_large_gatherings              0.227675              0.180907
# behavioral_outside_home                  0.220348              0.163382
# behavioral_touch_face                    0.335335              0.104335
# doctor_recc_h1n1                         0.068145              0.084282
# doctor_recc_seasonal                     0.074088              0.069481
# chronic_med_condition                    0.039435              0.068113
# child_under_6_months                    -0.000414              0.039726
# health_worker                            0.001180              0.069992
# health_insurance                         0.032662             -0.040257
# opinion_h1n1_vacc_effective              0.104317              0.043002
# opinion_h1n1_risk                        0.129188              0.115158
# opinion_h1n1_sick_from_vacc              0.142265              0.095864
# opinion_seas_vacc_effective              0.112245              0.049258
# opinion_seas_risk                        0.133850              0.106315
# opinion_seas_sick_from_vacc              0.087983              0.078267
# household_adults                         0.026497              0.008840
# household_children                       0.047839              0.005663
#
#                              behavioral_wash_hands  \
# h1n1_vaccine                              0.074712
# seasonal_vaccine                          0.112414
# h1n1_concern                              0.291068
# h1n1_knowledge                            0.088010
# behavioral_antiviral_meds                 0.064119
# behavioral_avoidance                      0.338130
# behavioral_face_mask                      0.083363
# behavioral_wash_hands                     1.000000
# behavioral_large_gatherings               0.195364
# behavioral_outside_home                   0.192619
# behavioral_touch_face                     0.365064
# doctor_recc_h1n1                          0.088729
# doctor_recc_seasonal                      0.102044
# chronic_med_condition                     0.030260
# child_under_6_months                      0.036188
# health_worker                             0.053761
# health_insurance                          0.031919
# opinion_h1n1_vacc_effective               0.131807
# opinion_h1n1_risk                         0.177711
# opinion_h1n1_sick_from_vacc               0.163299
# opinion_seas_vacc_effective               0.138282
# opinion_seas_risk                         0.175515
# opinion_seas_sick_from_vacc               0.095950
# household_adults                          0.017651
# household_children                        0.052621
#
#                              behavioral_large_gatherings  \
# h1n1_vaccine                                    0.017822
# seasonal_vaccine                                0.064025
# h1n1_concern                                    0.259242
# h1n1_knowledge                                 -0.045385
# behavioral_antiviral_meds                       0.106287
# behavioral_avoidance                            0.227675
# behavioral_face_mask                            0.180907
# behavioral_wash_hands                           0.195364
# behavioral_large_gatherings                     1.000000
# behavioral_outside_home                         0.584085
# behavioral_touch_face                           0.253683
# doctor_recc_h1n1                                0.082242
# doctor_recc_seasonal                            0.093557
# chronic_med_condition                           0.104721
# child_under_6_months                            0.021168
# health_worker                                  -0.032319
# health_insurance                               -0.059000
# opinion_h1n1_vacc_effective                     0.055668
# opinion_h1n1_risk                               0.115254
# opinion_h1n1_sick_from_vacc                     0.179292
# opinion_seas_vacc_effective                     0.093324
# opinion_seas_risk                               0.127798
# opinion_seas_sick_from_vacc                     0.124246
# household_adults                               -0.036554
# household_children                             -0.011233
#
#                              behavioral_outside_home  behavioral_touch_face  \
# h1n1_vaccine                                0.021768               0.071648
# seasonal_vaccine                            0.053509               0.120228
# h1n1_concern                                0.250697               0.248786
# h1n1_knowledge                             -0.063482               0.086909
# behavioral_antiviral_meds                   0.127679               0.070868
# behavioral_avoidance                        0.220348               0.335335
# behavioral_face_mask                        0.163382               0.104335
# behavioral_wash_hands                       0.192619               0.365064
# behavioral_large_gatherings                 0.584085               0.253683
# behavioral_outside_home                     1.000000               0.267719
# behavioral_touch_face                       0.267719               1.000000
# doctor_recc_h1n1                            0.070346               0.088221
# doctor_recc_seasonal                        0.085622               0.100808
# chronic_med_condition                       0.098858               0.028876
# child_under_6_months                        0.018195               0.026640
# health_worker                              -0.034619               0.067648
# health_insurance                           -0.061381               0.011024
# opinion_h1n1_vacc_effective                 0.056771               0.102845
# opinion_h1n1_risk                           0.112681               0.145638
# opinion_h1n1_sick_from_vacc                 0.166430               0.137901
# opinion_seas_vacc_effective                 0.083213               0.110917
# opinion_seas_risk                           0.114996               0.143937
# opinion_seas_sick_from_vacc                 0.128918               0.094033
# household_adults                           -0.033192               0.003095
# household_children                         -0.012060               0.027213
#
#                              doctor_recc_h1n1  doctor_recc_seasonal  \
# h1n1_vaccine                         0.393890              0.209864
# seasonal_vaccine                     0.198607              0.369190
# h1n1_concern                         0.152314              0.136396
# h1n1_knowledge                       0.095197              0.073031
# behavioral_antiviral_meds            0.051235              0.030909
# behavioral_avoidance                 0.068145              0.074088
# behavioral_face_mask                 0.084282              0.069481
# behavioral_wash_hands                0.088729              0.102044
# behavioral_large_gatherings          0.082242              0.093557
# behavioral_outside_home              0.070346              0.085622
# behavioral_touch_face                0.088221              0.100808
# doctor_recc_h1n1                     1.000000              0.591868
# doctor_recc_seasonal                 0.591868              1.000000
# chronic_med_condition                0.158275              0.213806
# child_under_6_months                 0.079389              0.036832
# health_worker                        0.101639              0.059402
# health_insurance                     0.067157              0.117195
# opinion_h1n1_vacc_effective          0.168780              0.125218
# opinion_h1n1_risk                    0.245555              0.161228
# opinion_h1n1_sick_from_vacc          0.100020              0.062871
# opinion_seas_vacc_effective          0.127683              0.208070
# opinion_seas_risk                    0.198281              0.237085
# opinion_seas_sick_from_vacc          0.044837              0.011036
# household_adults                     0.008171             -0.037067
# household_children                   0.026958             -0.051421
#
#                              chronic_med_condition  child_under_6_months  \
# h1n1_vaccine                              0.095207              0.066962
# seasonal_vaccine                          0.170174              0.012097
# h1n1_concern                              0.096359              0.050583
# h1n1_knowledge                           -0.018905              0.024308
# behavioral_antiviral_meds                 0.008465              0.028788
# behavioral_avoidance                      0.039435             -0.000414
# behavioral_face_mask                      0.068113              0.039726
# behavioral_wash_hands                     0.030260              0.036188
# behavioral_large_gatherings               0.104721              0.021168
# behavioral_outside_home                   0.098858              0.018195
# behavioral_touch_face                     0.028876              0.026640
# doctor_recc_h1n1                          0.158275              0.079389
# doctor_recc_seasonal                      0.213806              0.036832
# chronic_med_condition                     1.000000             -0.001349
# child_under_6_months                     -0.001349              1.000000
# health_worker                            -0.026481              0.079078
# health_insurance                          0.066088             -0.026836
# opinion_h1n1_vacc_effective               0.043526              0.012235
# opinion_h1n1_risk                         0.111842              0.073623
# opinion_h1n1_sick_from_vacc               0.069886              0.029007
# opinion_seas_vacc_effective               0.112117              0.004072
# opinion_seas_risk                         0.157351              0.048260
# opinion_seas_sick_from_vacc               0.037486              0.032501
# household_adults                         -0.076951              0.044906
# household_children                       -0.116512              0.099035
#
#                              health_worker  health_insurance  \
# h1n1_vaccine                      0.169768          0.121170
# seasonal_vaccine                  0.127311          0.200858
# h1n1_concern                      0.034141         -0.003231
# h1n1_knowledge                    0.174527          0.119876
# behavioral_antiviral_meds         0.009465         -0.063988
# behavioral_avoidance              0.001180          0.032662
# behavioral_face_mask              0.069992         -0.040257
# behavioral_wash_hands             0.053761          0.031919
# behavioral_large_gatherings      -0.032319         -0.059000
# behavioral_outside_home          -0.034619         -0.061381
# behavioral_touch_face             0.067648          0.011024
# doctor_recc_h1n1                  0.101639          0.067157
# doctor_recc_seasonal              0.059402          0.117195
# chronic_med_condition            -0.026481          0.066088
# child_under_6_months              0.079078         -0.026836
# health_worker                     1.000000          0.046680
# health_insurance                  0.046680          1.000000
# opinion_h1n1_vacc_effective       0.061880          0.050003
# opinion_h1n1_risk                 0.112019          0.015851
# opinion_h1n1_sick_from_vacc       0.004255         -0.024787
# opinion_seas_vacc_effective       0.031084          0.087806
# opinion_seas_risk                 0.084632          0.055308
# opinion_seas_sick_from_vacc      -0.025284         -0.060023
# household_adults                  0.016952         -0.060171
# household_children                0.042999         -0.067938
#
#                              opinion_h1n1_vacc_effective  opinion_h1n1_risk  \
# h1n1_vaccine                                    0.291602           0.305840
# seasonal_vaccine                                0.201753           0.219161
# h1n1_concern                                    0.220374           0.386032
# h1n1_knowledge                                  0.128278           0.076609
# behavioral_antiviral_meds                       0.036185           0.091523
# behavioral_avoidance                            0.104317           0.129188
# behavioral_face_mask                            0.043002           0.115158
# behavioral_wash_hands                           0.131807           0.177711
# behavioral_large_gatherings                     0.055668           0.115254
# behavioral_outside_home                         0.056771           0.112681
# behavioral_touch_face                           0.102845           0.145638
# doctor_recc_h1n1                                0.168780           0.245555
# doctor_recc_seasonal                            0.125218           0.161228
# chronic_med_condition                           0.043526           0.111842
# child_under_6_months                            0.012235           0.073623
# health_worker                                   0.061880           0.112019
# health_insurance                                0.050003           0.015851
# opinion_h1n1_vacc_effective                     1.000000           0.259329
# opinion_h1n1_risk                               0.259329           1.000000
# opinion_h1n1_sick_from_vacc                     0.062752           0.337511
# opinion_seas_vacc_effective                     0.444043           0.227141
# opinion_seas_risk                               0.258656           0.564522
# opinion_seas_sick_from_vacc                     0.009780           0.199404
# household_adults                                0.018416           0.031450
# household_children                             -0.001931           0.094713
#
#                              opinion_h1n1_sick_from_vacc  \
# h1n1_vaccine                                    0.059032
# seasonal_vaccine                                0.030128
# h1n1_concern                                    0.368674
# h1n1_knowledge                                 -0.026393
# behavioral_antiviral_meds                       0.071785
# behavioral_avoidance                            0.142265
# behavioral_face_mask                            0.095864
# behavioral_wash_hands                           0.163299
# behavioral_large_gatherings                     0.179292
# behavioral_outside_home                         0.166430
# behavioral_touch_face                           0.137901
# doctor_recc_h1n1                                0.100020
# doctor_recc_seasonal                            0.062871
# chronic_med_condition                           0.069886
# child_under_6_months                            0.029007
# health_worker                                   0.004255
# health_insurance                               -0.024787
# opinion_h1n1_vacc_effective                     0.062752
# opinion_h1n1_risk                               0.337511
# opinion_h1n1_sick_from_vacc                     1.000000
# opinion_seas_vacc_effective                     0.072154
# opinion_seas_risk                               0.271516
# opinion_seas_sick_from_vacc                     0.502192
# household_adults                                0.014957
# household_children                              0.073595
#
#                              opinion_seas_vacc_effective  opinion_seas_risk  \
# h1n1_vaccine                                    0.195961           0.256199
# seasonal_vaccine                                0.397874           0.389286
# h1n1_concern                                    0.222948           0.336218
# h1n1_knowledge                                  0.081695           0.077751
# behavioral_antiviral_meds                       0.022263           0.082382
# behavioral_avoidance                            0.112245           0.133850
# behavioral_face_mask                            0.049258           0.106315
# behavioral_wash_hands                           0.138282           0.175515
# behavioral_large_gatherings                     0.093324           0.127798
# behavioral_outside_home                         0.083213           0.114996
# behavioral_touch_face                           0.110917           0.143937
# doctor_recc_h1n1                                0.127683           0.198281
# doctor_recc_seasonal                            0.208070           0.237085
# chronic_med_condition                           0.112117           0.157351
# child_under_6_months                            0.004072           0.048260
# health_worker                                   0.031084           0.084632
# health_insurance                                0.087806           0.055308
# opinion_h1n1_vacc_effective                     0.444043           0.258656
# opinion_h1n1_risk                               0.227141           0.564522
# opinion_h1n1_sick_from_vacc                     0.072154           0.271516
# opinion_seas_vacc_effective                     1.000000           0.366353
# opinion_seas_risk                               0.366353           1.000000
# opinion_seas_sick_from_vacc                    -0.036707           0.194085
# household_adults                               -0.030105           0.011239
# household_children                             -0.085451           0.028903
#
#                              opinion_seas_sick_from_vacc  household_adults  \
# h1n1_vaccine                                   -0.002808          0.013360
# seasonal_vaccine                               -0.075427         -0.058912
# h1n1_concern                                    0.225148         -0.013091
# h1n1_knowledge                                 -0.072194          0.036928
# behavioral_antiviral_meds                       0.076568          0.040678
# behavioral_avoidance                            0.087983          0.026497
# behavioral_face_mask                            0.078267          0.008840
# behavioral_wash_hands                           0.095950          0.017651
# behavioral_large_gatherings                     0.124246         -0.036554
# behavioral_outside_home                         0.128918         -0.033192
# behavioral_touch_face                           0.094033          0.003095
# doctor_recc_h1n1                                0.044837          0.008171
# doctor_recc_seasonal                            0.011036         -0.037067
# chronic_med_condition                           0.037486         -0.076951
# child_under_6_months                            0.032501          0.044906
# health_worker                                  -0.025284          0.016952
# health_insurance                               -0.060023         -0.060171
# opinion_h1n1_vacc_effective                     0.009780          0.018416
# opinion_h1n1_risk                               0.199404          0.031450
# opinion_h1n1_sick_from_vacc                     0.502192          0.014957
# opinion_seas_vacc_effective                    -0.036707         -0.030105
# opinion_seas_risk                               0.194085          0.011239
# opinion_seas_sick_from_vacc                     1.000000          0.024791
# household_adults                                0.024791          1.000000
# household_children                              0.066995          0.238291
#
#                              household_children
# h1n1_vaccine                          -0.002012
# seasonal_vaccine                      -0.121141
# h1n1_concern                           0.054138
# h1n1_knowledge                         0.054768
# behavioral_antiviral_meds              0.086445
# behavioral_avoidance                   0.047839
# behavioral_face_mask                   0.005663
# behavioral_wash_hands                  0.052621
# behavioral_large_gatherings           -0.011233
# behavioral_outside_home               -0.012060
# behavioral_touch_face                  0.027213
# doctor_recc_h1n1                       0.026958
# doctor_recc_seasonal                  -0.051421
# chronic_med_condition                 -0.116512
# child_under_6_months                   0.099035
# health_worker                          0.042999
# health_insurance                      -0.067938
# opinion_h1n1_vacc_effective           -0.001931
# opinion_h1n1_risk                      0.094713
# opinion_h1n1_sick_from_vacc            0.073595
# opinion_seas_vacc_effective           -0.085451
# opinion_seas_risk                      0.028903
# opinion_seas_sick_from_vacc            0.066995
# household_adults                       0.238291
# household_children                     1.000000

# %%
# Checking out highest positive correlations

s = df.corr(method='spearman').unstack().sort_values(kind="quicksort", ascending=False).drop_duplicates()
print(s[1:20])
# Out:
# doctor_recc_seasonal         doctor_recc_h1n1               0.591868
# behavioral_outside_home      behavioral_large_gatherings    0.584085
# opinion_seas_risk            opinion_h1n1_risk              0.564522
# opinion_h1n1_sick_from_vacc  opinion_seas_sick_from_vacc    0.502192
# opinion_h1n1_vacc_effective  opinion_seas_vacc_effective    0.444043
# seasonal_vaccine             opinion_seas_vacc_effective    0.397874
# h1n1_vaccine                 doctor_recc_h1n1               0.393890
# seasonal_vaccine             opinion_seas_risk              0.389286
# h1n1_concern                 opinion_h1n1_risk              0.386032
# h1n1_vaccine                 seasonal_vaccine               0.377143
# doctor_recc_seasonal         seasonal_vaccine               0.369190
# h1n1_concern                 opinion_h1n1_sick_from_vacc    0.368674
# opinion_seas_vacc_effective  opinion_seas_risk              0.366353
# behavioral_wash_hands        behavioral_touch_face          0.365064
# behavioral_avoidance         behavioral_wash_hands          0.338130
# opinion_h1n1_risk            opinion_h1n1_sick_from_vacc    0.337511
# opinion_seas_risk            h1n1_concern                   0.336218
# behavioral_touch_face        behavioral_avoidance           0.335335
# h1n1_vaccine                 opinion_h1n1_risk              0.305840
# dtype: float64

# %% [markdown]
# ### Relevant positive correlations between features (>0.5)
# - doctor_recc_h1n1 AND doctor_recc_seasonal
# - behavioral_large_gatherings AND behavioral_outside_home
# - opinion_seas_risk AND opinion_h1n1_risk
# - opinion_h1n1_sick_from_vacc AND opinion_seas_sick_from_vacc
# #### further positive correlations (>0.35)
# - opinion_h1n1_vacc_effective AND opinion_seas_vacc_effective
# - opinion_seas_risk AND seasonal_vaccine
# - opinion_h1n1_risk AND h1n1_concern
# - seasonal_vaccine  AND doctor_recc_seasonal
# - behavioral_touch_face AND behavioral_wash_hands
# - opinion_seas_risk AND opinion_seas_vacc_effective
# - h1n1_concern AND opinion_h1n1_sick_from_vacc
#
# Assumption: correlations below 0.35 can be neglected.
# When deciding about dropping of features, we should first consider correlations above 0.5

# %%
# Checking out highest negative correlations

s_neg = df.corr(method='spearman').unstack().sort_values(kind="quicksort", ascending=True).drop_duplicates()
print(s_neg[:5])
# Out:
# household_children           seasonal_vaccine        -0.121141
#                              chronic_med_condition   -0.116512
# opinion_seas_vacc_effective  household_children      -0.085451
# household_adults             chronic_med_condition   -0.076951
# opinion_seas_sick_from_vacc  seasonal_vaccine        -0.075427
# dtype: float64

# %% [markdown]
# - negative correlations are very small so we don't need to consider them

# %%
# maybe make plots for all highly correlated features

# %% [markdown]
# ## Investigating causality between features

# %%
# pip install dowhy
import dowhy
from dowhy import CausalModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/hq/qn47frx13tx83lx6lj1c_2yh0000gn/T/ipykernel_55139/2087588030.py in <module>
#       1 # pip install dowhy
# ----> 2 import dowhy
#       3 from dowhy import CausalModel
#
# ModuleNotFoundError: No module named 'dowhy'
